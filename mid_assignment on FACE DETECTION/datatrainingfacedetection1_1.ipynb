# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import cv2
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 from tensorflow.keras import layers
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
DATA_PATH = '/content/drive/MyDrive/Imagedata'

if os.path.exists(DATA_PATH):
    folders = [folder for folder in os.listdir(DATA_PATH) if os.path.isdir(os.path.join(DATA_PATH, folder))]

    print("Folders inside 'Imagedata':")
    for folder in folders:
        print(folder)
else:
    print(f"Directory '{DATA_PATH}' not found.")
# Out:
# Folders inside 'Imagedata':
# ESM-E MOULA CHOWDHURY ABHA
# ABDULLAH AL SHAHRIAR
# ARNAB BISHAKH SARKER
# AL-NAFI
# ASHIK AHAMED
# ASHA ISLAM
# BORSHON ALFRED GOMES
# BISHANATH TARAFDER
# ELMA ISLAM
# AHMED IMTIAZ
# MAHFUZUR RAHMAN FERDOUS
# KHANDAKER AZNAN ALAM SEAM
# FAIZA BINTE ZAMAN
# MAHNAZ HOSSAIN
# MD ABID HASAN RAPPY
# MAHBUBUL ISLAM ABDULLAH
# MAHASHETAB HASSAN
# IMAM HASAN JAMI
# MD ABU ZAYED KHAN
# FAHIM RAHMAN
# MD MUSFIQUR RAHMAN
# MD JAHID HASSAN
# MD ATIK ULLAH KHAN
# MD MUNTASIR AREFIN NAEEM
# MD NAIMUR RAHMAN
# MD ANAS KHAN
# MD FARDIN AMIN RIYAD
# MD ASRAFUL KABIR SOHAN
# MD NAFIZ AHMED
# MD IMTIAJ ALAM SAJIN
# MD TAREK MAHMUD
# MD SAIFUR RAHMAN SADI
# MD NAZMUL HASSAN BHUIYAN
# MD WAHIDUZZAMAN SUVA
# MD RIFAT SHIKDAR
# MD SHANZID HASAN
# MD TOYABUR RAHAMAN
# MD SAJID ISLAM KHAN
# MD NAKIB MUNSIF
# MD TANZIB HOSAIN
# MOHAMMAD RAFIUL HAQUE
# MOHAMMAD BIN AB JALIL SHEAKH
# NAFIS MUBASSHIR SHAH
# MOHAMMAD NUR
# MOHIBUL ALAM ANANDA
# MOMOTAZ YEASMIN
# ...

# %%
classes = os.listdir(DATA_PATH)
print(classes)
# Out:
# ['ESM-E MOULA CHOWDHURY ABHA', 'ABDULLAH AL SHAHRIAR', 'ARNAB BISHAKH SARKER', 'AL-NAFI', 'ASHIK AHAMED', 'ASHA ISLAM', 'BORSHON ALFRED GOMES', 'BISHANATH TARAFDER', 'ELMA ISLAM', 'AHMED IMTIAZ', 'MAHFUZUR RAHMAN FERDOUS', 'KHANDAKER AZNAN ALAM SEAM', 'FAIZA BINTE ZAMAN', 'MAHNAZ HOSSAIN', 'MD ABID HASAN RAPPY', 'MAHBUBUL ISLAM ABDULLAH', 'MAHASHETAB HASSAN', 'IMAM HASAN JAMI', 'MD ABU ZAYED KHAN', 'FAHIM RAHMAN', 'MD MUSFIQUR RAHMAN', 'MD JAHID HASSAN', 'MD ATIK ULLAH KHAN', 'MD MUNTASIR AREFIN NAEEM', 'MD NAIMUR RAHMAN', 'MD ANAS KHAN', 'MD FARDIN AMIN RIYAD', 'MD ASRAFUL KABIR SOHAN', 'MD NAFIZ AHMED', 'MD IMTIAJ ALAM SAJIN', 'MD TAREK MAHMUD', 'MD SAIFUR RAHMAN SADI', 'MD NAZMUL HASSAN BHUIYAN', 'MD WAHIDUZZAMAN SUVA', 'MD RIFAT SHIKDAR', 'MD SHANZID HASAN', 'MD TOYABUR RAHAMAN', 'MD SAJID ISLAM KHAN', 'MD NAKIB MUNSIF', 'MD TANZIB HOSAIN', 'MOHAMMAD RAFIUL HAQUE', 'MOHAMMAD BIN AB JALIL SHEAKH', 'NAFIS MUBASSHIR SHAH', 'MOHAMMAD NUR', 'MOHIBUL ALAM ANANDA', 'MOMOTAZ YEASMIN', 'M
# ...

# %%
train_data = []
for i, c in enumerate(classes):
    path = os.path.join(DATA_PATH, c)
    for img_name in tqdm(os.listdir(path)):
        img_path = os.path.join(path, img_name)
        img_arr = cv2.imread(img_path)
        if img_arr is not None:  # Check if image reading was successful
            img_arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            img_arr = cv2.resize(img_arr, (128, 128))  # Resize image
            plt.imshow(img_arr)
            plt.show()  # Display image
            train_data.append((img_arr, i))  # Append as tuple (img_arr, label)

print(len(train_data))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
random.shuffle(train_data)

# %%
train_imgs = []
train_labels = []
for img,label in train_data:
  train_imgs.append(img)
  train_labels.append(label)

# %%
import numpy as np
train_imgs_np = np.array(train_imgs)
train_labels_np = np.array(train_labels)

print(train_imgs_np.shape,train_labels_np.shape)
# Out:
# (537, 128, 128, 3) (537,)

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(128,128,3)),
    layers.Conv2D(filters=128, kernel_size=(5,5), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(128, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 124, 124, 128)     9728
#
#  max_pooling2d (MaxPooling2  (None, 62, 62, 128)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 64)        73792
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 128)               1605760
#
#  dense_1 (Dense)             (None, 128)               16512
#
# ...
# Total params: 1742720 (6.65 MB)
# Trainable params: 1742720 (6.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
h = model.fit(x=train_imgs_np, y=train_labels_np, epochs=10, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/10
# 7/7 [==============================] - 44s 6s/step - loss: 5.1035 - accuracy: 0.4895 - val_loss: 4.5833 - val_accuracy: 0.1389
# Epoch 2/10
# 7/7 [==============================] - 43s 6s/step - loss: 1.1739 - accuracy: 0.7203 - val_loss: 3.7769 - val_accuracy: 0.2407
# Epoch 3/10
# 7/7 [==============================] - 42s 6s/step - loss: 0.7779 - accuracy: 0.8135 - val_loss: 4.4079 - val_accuracy: 0.2685
# Epoch 4/10
# 7/7 [==============================] - 52s 8s/step - loss: 0.3187 - accuracy: 0.9371 - val_loss: 5.5349 - val_accuracy: 0.2870
# Epoch 5/10
# 7/7 [==============================] - 43s 6s/step - loss: 0.0970 - accuracy: 0.9767 - val_loss: 7.7766 - val_accuracy: 0.2778
# Epoch 6/10
# 7/7 [==============================] - 47s 7s/step - loss: 0.0146 - accuracy: 0.9977 - val_loss: 9.6116 - val_accuracy: 0.2685
# Epoch 7/10
# 7/7 [==============================] - 42s 6s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 10.3400 - val_accuracy: 0.2593
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
model.save('/content/drive/MyDrive/datatrainingfacedetection1')

# %%
import tensorflow as tf
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
import cv2

model = tf.keras.models.load_model('/content/drive/MyDrive/datatrainingfacedetection1')

classes = ["ESM-E MOULA CHOWDHURY ABHA", "ABDULLAH AL SHAHRIAR", "ARNAB BISHAKH SARKER", "AL-NAFI", "ASHIK AHAMED", "ASHA ISLAM", "BORSHON ALFRED GOMES", "BISHANATH TARAFDER", "ELMA ISLAM", "AHMED IMTIAZ", "MAHFUZUR RAHMAN FERDOUS", "KHANDAKER AZNAN ALAM SEAM", "FAIZA BINTE ZAMAN", "MAHNAZ HOSSAIN", "MD ABID HASAN RAPPY", "MAHBUBUL ISLAM ABDULLAH", "MAHASHETAB HASSAN", "IMAM HASAN JAMI", "MD ABU ZAYED KHAN", "FAHIM RAHMAN", "MD MUSFIQUR RAHMAN", "MD JAHID HASSAN", "MD ATIK ULLAH KHAN", "MD MUNTASIR AREFIN NAEEM", "MD NAIMUR RAHMAN", "MD ANAS KHAN", "MD FARDIN AMIN RIYAD", "MD ASRAFUL KABIR SOHAN", "MD NAFIZ AHMED", "MD IMTIAJ ALAM SAJIN", "MD TAREK MAHMUD", "MD SAIFUR RAHMAN SADI", "MD NAZMUL HASSAN BHUIYAN", "MD WAHIDUZZAMAN SUVA", "MD RIFAT SHIKDAR", "MD SHANZID HASAN", "MD TOYABUR RAHAMAN", "MD SAJID ISLAM KHAN", "MD NAKIB MUNSIF", "MD TANZIB HOSAIN", "MOHAMMAD RAFIUL HAQUE", "MOHAMMAD BIN AB JALIL SHEAKH", "NAFIS MUBASSHIR SHAH", "MOHAMMAD NUR", "MOHIBUL ALAM ANANDA", "MOMOTAZ YEASMIN", "MOHAMMED TANVIR HASSAN", "MREDUL MAHMUD AKASH", "NAHAR ISLAM NISHI", "MST ROKEYA KHATUN", "NUR MOHAMMAD", "NAORIN SULTANA", "RIDWAN AHMED ARMAN", "RAHAD-UL-ISLAM RABBY", "REZWAN AHMAD", "PARBOTI DAS PUJA", "S M FAISAL", "NILOY GHARAMI", "NAVID MAHFUZ NAYEEM", "SABBIR AHMED", "SUMAIYA SULTANA TARIN", "SHEIKH AKIB ALMAS", "SHAH MD MOHIBBULLAH SHOVON", "TAHFIM IBN KHAN", "SATYAJIT DAS", "SHOAIB AHMAD", "SHAHRIAR HOSSAIN", "SADAT BIN MASUD", "SRABONE RAXIT", "SYEDA HUMAIRA JABEEN", "TIRTHA BARUA", "TAHMID AL RAFID SIDDIQUE", "ZANNATUS SURIYA SUCY", "ZOBAYER ALAM", "TARIKUL ISLAM NISHAT", "THASNOVA SININ"]

def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
        async function takePhoto(quality) {
            const div = document.createElement('div');
            const capture = document.createElement('button');
            capture.textContent = 'Capture';
            div.appendChild(capture);

            const video = document.createElement('video');
            video.style.display = 'block';
            const stream = await navigator.mediaDevices.getUserMedia({video: true});

            document.body.appendChild(div);
            div.appendChild(video);
            video.srcObject = stream;
            await video.play();

            google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

            await new Promise((resolve) => capture.onclick = resolve);

            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            canvas.getContext('2d').drawImage(video, 0, 0);
            stream.getVideoTracks()[0].stop();
            div.remove();
            return canvas.toDataURL('image/jpeg', quality);
        }
    ''')
    display(js)
    data = eval_js('takePhoto({})'.format(quality))
    binary = b64decode(data.split(',')[1])
    with open(filename, 'wb') as f:
        f.write(binary)
    return filename

try:
    filename = take_photo()
    print('Saved to {}'.format(filename))

    img = cv2.imread(filename)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (128, 128))
    img = img / 255.0


    predictions = model.predict(np.expand_dims(img, axis=0))


    predicted_class = np.argmax(predictions)
    predicted_label = classes[predicted_class]

    print("Predicted Label:", predicted_label)

except Exception as err:
    print(str(err))
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x793a97f3dbd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Saved to photo.jpg
# 1/1 [==============================] - 0s 114ms/step
# Predicted Label: RAHAD-UL-ISLAM RABBY
